# %% [markdown]
# ---
# title: null
# ---
#
# ## Linearkombination von Vektoren
#
# Gegeben seien die Vektoren
#
# $$
# \vec{v}_1=
# \begin{pmatrix}
# 1\\
# 2\\
# -1
# \end{pmatrix},
# \qquad
# \vec{v}_2=
# \begin{pmatrix}
# 2\\
# -1\\
# 3
# \end{pmatrix}
# $$
#
# und der Vektor
#
# $$
# \vec{w}=
# \begin{pmatrix}
# 4\\
# 3\\
# 1
# \end{pmatrix}.
# $$
#
# Untersuchen Sie, ob sich der Vektor $\vec{w}$ als **Linearkombination** der Vektoren $\vec{v}_1$ und $\vec{v}_2$ darstellen lässt.
#
# Bestimmen Sie dazu die Skalare $\lambda_1,\lambda_2\in\mathbb{R}$, sodass
#
# $$
# \vec{w}
# =
# \lambda_1\vec{v}_1
# +
# \lambda_2\vec{v}_2.
# $$
#
# Geben Sie anschließend die Linearkombination explizit an.

# %% [markdown]
# ## Lösung
#
# Die Lösung ist in einzelne Rechenschritte unterteilt.
#
# Bearbeiten Sie zunächst jeden Schritt selbstständig und öffnen Sie anschließend das jeweilige Zwischenergebnis zur Kontrolle.

# %% [markdown]
# :::{dropdown} Aufstellen des linearen Gleichungssystems
#
# Gesucht sind $\lambda_1,\lambda_2\in\mathbb{R}$ mit
#
# $$
# \lambda_1\vec{v}_1
# +
# \lambda_2\vec{v}_2
# =
# \vec{w}.
# $$
#
# Einsetzen der Vektoren ergibt
#
# $$
# \lambda_1
# \begin{pmatrix}
# 1\\
# 2\\
# -1
# \end{pmatrix}
# +
# \lambda_2
# \begin{pmatrix}
# 2\\
# -1\\
# 3
# \end{pmatrix}
# =
# \begin{pmatrix}
# 4\\
# 3\\
# 1
# \end{pmatrix}.
# $$
#
# Durch komponentenweisen Vergleich erhalten wir
#
# $$
# \begin{aligned}
# \lambda_1+2\lambda_2 &=4,\\
# 2\lambda_1-\lambda_2 &=3,\\
# -\lambda_1+3\lambda_2 &=1.
# \end{aligned}
# $$
#
# Die erweiterte Koeffizientenmatrix lautet
#
# $$
# \boxed{
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 2 & -1 & 3\\
# -1 & 3 & 1
# \end{array}
# \right)
# }
# $$
# :::

# %% [markdown]
# ::::{dropdown} Durchführung der Elimination
#
# Ausgangspunkt ist die erweiterte Koeffizientenmatrix
#
# $$
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 2 & -1 & 3\\
# -1 & 3 & 1
# \end{array}
# \right).
# $$
#
#
# :::{dropdown} Schritt 1 – Eintrag in der ersten Spalte eliminieren
#
# Wir verwenden
#
# $$
# Z_2\leftarrow Z_2-2Z_1.
# $$
#
# Es ergibt sich
#
# $$
# Z_2:
# \qquad
# (2,\;-1\mid3)
# -
# 2(1,\;2\mid4)
# $$
#
# und damit
#
# $$
# Z_2=(0,\;-5\mid-5).
# $$
#
# Die Matrix lautet nun
#
# $$
# \boxed{
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 0 & -5 & -5\\
# -1 & 3 & 1
# \end{array}
# \right)
# }
# $$
# :::
#
#
# :::{dropdown} Schritt 2 – Weiteren Eintrag in der ersten Spalte eliminieren
#
# Nun verwenden wir
#
# $$
# Z_3\leftarrow Z_3+Z_1.
# $$
#
# Es ergibt sich
#
# $$
# Z_3:
# \qquad
# (-1,\;3\mid1)
# +
# (1,\;2\mid4)
# $$
#
# und damit
#
# $$
# Z_3=(0,\;5\mid5).
# $$
#
# Die Matrix lautet nun
#
# $$
# \boxed{
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 0 & -5 & -5\\
# 0 & 5 & 5
# \end{array}
# \right)
# }
# $$
# :::
#
#
# :::{dropdown} Schritt 3 – Eintrag unterhalb des zweiten Pivotelements eliminieren
#
# Wir verwenden
#
# $$
# Z_3\leftarrow Z_3+Z_2.
# $$
#
# Damit ergibt sich
#
# $$
# Z_3=(0,\;0\mid0).
# $$
#
# Die Matrix lautet
#
# $$
# \boxed{
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 0 & -5 & -5\\
# 0 & 0 & 0
# \end{array}
# \right)
# }
# $$
# :::
#
#
# :::{dropdown} Schritt 4 – Zweites Pivotelement normieren
#
# Wir verwenden
#
# $$
# Z_2\leftarrow-\frac{1}{5}Z_2.
# $$
#
# Damit erhalten wir
#
# $$
# \boxed{
# \left(
# \begin{array}{cc|c}
# 1 & 2 & 4\\
# 0 & 1 & 1\\
# 0 & 0 & 0
# \end{array}
# \right)
# }
# $$
# :::
#
# ::::

# %% [markdown]
# :::{dropdown} Rückwärtseinsetzen
#
# Aus der zweiten Zeile folgt
#
# $$
# \lambda_2=1.
# $$
#
# Aus der ersten Zeile ergibt sich
#
# $$
# \lambda_1+2\lambda_2=4.
# $$
#
# Mit $\lambda_2=1$ folgt
#
# $$
# \lambda_1+2=4
# $$
#
# und damit
#
# $$
# \lambda_1=2.
# $$
# :::

# %% [markdown]
# :::{dropdown} Gesamtlösung anzeigen
#
# Es gilt
#
# $$
# \lambda_1=2,
# \qquad
# \lambda_2=1.
# $$
#
# Damit lässt sich $\vec{w}$ als Linearkombination von $\vec{v}_1$ und $\vec{v}_2$ darstellen:
#
# $$
# \boxed{
# \vec{w}
# =
# 2\vec{v}_1+\vec{v}_2
# }
# $$
#
# Zur Kontrolle:
#
# $$
# 2
# \begin{pmatrix}
# 1\\
# 2\\
# -1
# \end{pmatrix}
# +
# \begin{pmatrix}
# 2\\
# -1\\
# 3
# \end{pmatrix}
# =
# \begin{pmatrix}
# 4\\
# 3\\
# 1
# \end{pmatrix}.
# $$
#
# Somit gilt
#
# $$
# \boxed{
# \vec{w}\in
# \operatorname{span}\{\vec{v}_1,\vec{v}_2\}.
# }
# $$
# :::
